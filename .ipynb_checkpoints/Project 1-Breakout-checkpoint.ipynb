# %% [markdown]
# # 1. Import Dependencies

# %%
import gym 
from stable_baselines3 import A2C
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_atari_env
import os

# %% [markdown]
# # 2. Test Environment

# %%
environment_name = "Breakout-v0"

# %%
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:0.0
# Episode:2 Score:2.0
# Episode:3 Score:0.0
# Episode:4 Score:0.0
# Episode:5 Score:0.0

# %%
env.action_space.sample()
# Out:
# 1

# %%
env.observation_space.sample()
# Out:
# array([[[255,  87, 191],
#         [191, 150, 140],
#         [ 90, 232,  25],
#         ...,
#         [ 33, 143,   6],
#         [231,  97, 197],
#         [211, 207,  43]],
#
#        [[ 55, 241,  12],
#         [ 93, 137, 233],
#         [100, 176,   0],
#         ...,
#         [174, 148, 218],
#         [244, 226, 197],
#         [235, 184, 157]],
#
#        [[132,   9, 171],
#         [140,  23, 204],
#         [243, 226,  55],
#         ...,
#         [ 40,  31, 224],
#         [236,  46,  56],
#         [199, 219, 192]],
#
#        ...,
#
#        [[131, 111, 180],
#         [107, 156, 231],
#         [155, 244,  50],
#         ...,
#         [115, 160, 253],
#         [100,  87,  14],
#         [  1,  29, 168]],
#
#        [[ 66, 243, 200],
#         [ 52,  23, 251],
#         [173,   1,  63],
#         ...,
#         [205, 200,  18],
#         [196,  49, 123],
#         [245, 193, 207]],
#
#        [[181, 206,  90],
#         [ 77, 189, 206],
#         [ 95, 219,  48],
#         ...,
#         [163,  61, 169],
#         [ 62, 248, 149],
#         [117, 118,  90]]], dtype=uint8)

# %% [markdown]
# # 3. Vectorise Environment and Train Model

# %%
env = make_atari_env('Breakout-v0', n_envs=4, seed=0)

# %%
env = VecFrameStack(env, n_stack=4)

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = A2C("CnnPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=400000)
# Out:
# Logging to Training/Logs/A2C_1
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 284      |
# |    ep_rew_mean        | 1.63     |
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 100      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.057    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.389    |
# |    value_loss         | 0.27     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 292      |
# |    ep_rew_mean        | 1.73     |
# | time/                 |          |
# |    fps                | 255      |
# |    iterations         | 200      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | -0.0799  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.237    |
# |    value_loss         | 0.402    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 294      |
# |    ep_rew_mean        | 1.78     |
# | time/                 |          |
# |    fps                | 260      |
# |    iterations         | 300      |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 0.771    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.121   |
# |    value_loss         | 0.0882   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 298      |
# |    ep_rew_mean        | 1.84     |
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 400      |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.36    |
# |    explained_variance | 0.69     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.159   |
# |    value_loss         | 0.0309   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 307      |
# |    ep_rew_mean        | 2.02     |
# | time/                 |          |
# |    fps                | 264      |
# |    iterations         | 500      |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.36    |
# |    explained_variance | 0.868    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.0755  |
# |    value_loss         | 0.0164   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 309      |
# |    ep_rew_mean        | 2.04     |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 600      |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.16    |
# |    explained_variance | 0.981    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.00923  |
# |    value_loss         | 0.0147   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 317      |
# |    ep_rew_mean        | 2.18     |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 700      |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | 0.888    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.0341   |
# |    value_loss         | 0.0361   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 320      |
# |    ep_rew_mean        | 2.25     |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 800      |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.17    |
# |    explained_variance | 0.773    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.0605   |
# |    value_loss         | 0.0868   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 331      |
# |    ep_rew_mean        | 2.49     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 900      |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -1.24    |
# |    explained_variance | 0.928    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.0196   |
# |    value_loss         | 0.0264   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 329      |
# |    ep_rew_mean        | 2.46     |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 1000     |
# |    time_elapsed       | 73       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.26    |
# |    explained_variance | 0.868    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0667   |
# |    value_loss         | 0.0309   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 335      |
# |    ep_rew_mean        | 2.58     |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 1100     |
# |    time_elapsed       | 80       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.925   |
# |    explained_variance | 0.872    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.0223  |
# |    value_loss         | 0.034    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 336      |
# |    ep_rew_mean        | 2.6      |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 1200     |
# |    time_elapsed       | 88       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -1.32    |
# |    explained_variance | 0.354    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.176    |
# |    value_loss         | 0.0802   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 335      |
# |    ep_rew_mean        | 2.6      |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 1300     |
# |    time_elapsed       | 95       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.876   |
# |    explained_variance | 0.92     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.0888   |
# |    value_loss         | 0.0542   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 334      |
# |    ep_rew_mean        | 2.69     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 1400     |
# |    time_elapsed       | 103      |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | 0.933    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.251   |
# |    value_loss         | 0.0631   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 349      |
# |    ep_rew_mean        | 3.14     |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 1500     |
# |    time_elapsed       | 110      |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.605   |
# |    explained_variance | -2.2     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.112   |
# |    value_loss         | 0.628    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 374      |
# |    ep_rew_mean        | 3.73     |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 1600     |
# |    time_elapsed       | 117      |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -0.824   |
# |    explained_variance | -1.15    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.163   |
# |    value_loss         | 0.163    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 390      |
# |    ep_rew_mean        | 4.08     |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 1700     |
# |    time_elapsed       | 124      |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.699   |
# |    explained_variance | 0.735    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.215   |
# |    value_loss         | 0.274    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 409      |
# |    ep_rew_mean        | 4.43     |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 1800     |
# |    time_elapsed       | 131      |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.384   |
# |    explained_variance | 0.951    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.0463  |
# |    value_loss         | 0.0475   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 420      |
# |    ep_rew_mean        | 4.6      |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 1900     |
# |    time_elapsed       | 138      |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.753   |
# |    explained_variance | 0.806    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.11    |
# |    value_loss         | 0.111    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 413      |
# |    ep_rew_mean        | 4.4      |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 2000     |
# |    time_elapsed       | 146      |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -0.656   |
# |    explained_variance | 0.718    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0116  |
# |    value_loss         | 0.115    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 403      |
# |    ep_rew_mean        | 4.21     |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 2100     |
# |    time_elapsed       | 153      |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -0.248   |
# |    explained_variance | 0.973    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.0267  |
# |    value_loss         | 0.0101   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 404      |
# |    ep_rew_mean        | 4.3      |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 2200     |
# |    time_elapsed       | 161      |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -0.703   |
# |    explained_variance | 0.786    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.0123   |
# |    value_loss         | 0.0455   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 411      |
# |    ep_rew_mean        | 4.45     |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 2300     |
# |    time_elapsed       | 168      |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -0.313   |
# |    explained_variance | 0.803    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.0026   |
# |    value_loss         | 0.0413   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 416      |
# |    ep_rew_mean        | 4.58     |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 2400     |
# |    time_elapsed       | 176      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -0.155   |
# |    explained_variance | 0.922    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.0418   |
# |    value_loss         | 0.0607   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 435      |
# |    ep_rew_mean        | 4.97     |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 2500     |
# |    time_elapsed       | 183      |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -0.301   |
# |    explained_variance | 0.871    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.0731  |
# |    value_loss         | 0.0873   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 445       |
# |    ep_rew_mean        | 5.22      |
# | time/                 |           |
# |    fps                | 272       |
# |    iterations         | 2600      |
# |    time_elapsed       | 191       |
# |    total_timesteps    | 52000     |
# | train/                |           |
# |    entropy_loss       | -0.214    |
# |    explained_variance | 0.935     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | -0.000409 |
# |    value_loss         | 0.0423    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 451      |
# |    ep_rew_mean        | 5.2      |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 2700     |
# |    time_elapsed       | 198      |
# |    total_timesteps    | 54000    |
# | train/                |          |
# |    entropy_loss       | -0.353   |
# |    explained_variance | 0.453    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.123   |
# |    value_loss         | 0.103    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 447      |
# |    ep_rew_mean        | 5.08     |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 2800     |
# |    time_elapsed       | 205      |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -0.0905  |
# |    explained_variance | 0.928    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.00142 |
# |    value_loss         | 0.0488   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 462      |
# |    ep_rew_mean        | 5.42     |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 2900     |
# |    time_elapsed       | 213      |
# |    total_timesteps    | 58000    |
# | train/                |          |
# |    entropy_loss       | -0.388   |
# |    explained_variance | -0.0208  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.0981   |
# |    value_loss         | 0.231    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 455      |
# |    ep_rew_mean        | 5.25     |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 3000     |
# |    time_elapsed       | 220      |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -0.137   |
# |    explained_variance | 0.822    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.123   |
# |    value_loss         | 0.13     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 462      |
# |    ep_rew_mean        | 5.39     |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 3100     |
# |    time_elapsed       | 228      |
# |    total_timesteps    | 62000    |
# | train/                |          |
# |    entropy_loss       | -0.159   |
# |    explained_variance | 0.995    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.0021   |
# |    value_loss         | 0.00749  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 461      |
# |    ep_rew_mean        | 5.38     |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 3200     |
# |    time_elapsed       | 235      |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -0.275   |
# |    explained_variance | 0.417    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.0385   |
# |    value_loss         | 0.192    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 471      |
# |    ep_rew_mean        | 5.61     |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 3300     |
# |    time_elapsed       | 242      |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -0.188   |
# |    explained_variance | 0.593    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | -0.00231 |
# |    value_loss         | 0.095    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 468      |
# |    ep_rew_mean        | 5.51     |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 3400     |
# |    time_elapsed       | 249      |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -0.0351  |
# |    explained_variance | 0.711    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.00201 |
# |    value_loss         | 0.232    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 476      |
# |    ep_rew_mean        | 5.58     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 3500     |
# |    time_elapsed       | 255      |
# |    total_timesteps    | 70000    |
# | train/                |          |
# |    entropy_loss       | -0.281   |
# |    explained_variance | 0.965    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.0465   |
# |    value_loss         | 0.0236   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 481      |
# |    ep_rew_mean        | 5.65     |
# | time/                 |          |
# |    fps                | 275      |
# |    iterations         | 3600     |
# |    time_elapsed       | 261      |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -0.0479  |
# |    explained_variance | 0.933    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.00656 |
# |    value_loss         | 0.06     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 480      |
# |    ep_rew_mean        | 5.68     |
# | time/                 |          |
# |    fps                | 276      |
# |    iterations         | 3700     |
# |    time_elapsed       | 267      |
# |    total_timesteps    | 74000    |
# | train/                |          |
# |    entropy_loss       | -0.124   |
# |    explained_variance | 0.661    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.0105   |
# |    value_loss         | 0.0482   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 479      |
# |    ep_rew_mean        | 5.6      |
# | time/                 |          |
# |    fps                | 277      |
# |    iterations         | 3800     |
# |    time_elapsed       | 273      |
# |    total_timesteps    | 76000    |
# | train/                |          |
# |    entropy_loss       | -0.227   |
# |    explained_variance | 0.955    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.045    |
# |    value_loss         | 0.0517   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 492      |
# |    ep_rew_mean        | 5.84     |
# | time/                 |          |
# |    fps                | 279      |
# |    iterations         | 3900     |
# |    time_elapsed       | 279      |
# |    total_timesteps    | 78000    |
# | train/                |          |
# |    entropy_loss       | -0.0427  |
# |    explained_variance | 0.231    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.00232  |
# |    value_loss         | 0.286    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 488      |
# |    ep_rew_mean        | 5.76     |
# | time/                 |          |
# |    fps                | 280      |
# |    iterations         | 4000     |
# |    time_elapsed       | 285      |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -0.178   |
# |    explained_variance | 0.805    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.122   |
# |    value_loss         | 0.296    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 496      |
# |    ep_rew_mean        | 5.91     |
# | time/                 |          |
# |    fps                | 281      |
# |    iterations         | 4100     |
# |    time_elapsed       | 291      |
# |    total_timesteps    | 82000    |
# | train/                |          |
# |    entropy_loss       | -0.163   |
# |    explained_variance | 0.887    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.0355  |
# |    value_loss         | 0.0923   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 507      |
# |    ep_rew_mean        | 6.13     |
# | time/                 |          |
# |    fps                | 282      |
# |    iterations         | 4200     |
# |    time_elapsed       | 297      |
# |    total_timesteps    | 84000    |
# | train/                |          |
# |    entropy_loss       | -0.0694  |
# |    explained_variance | 0.931    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.00295 |
# |    value_loss         | 0.093    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 517      |
# |    ep_rew_mean        | 6.38     |
# | time/                 |          |
# |    fps                | 283      |
# |    iterations         | 4300     |
# |    time_elapsed       | 303      |
# |    total_timesteps    | 86000    |
# | train/                |          |
# |    entropy_loss       | -0.134   |
# |    explained_variance | 0.938    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.00346  |
# |    value_loss         | 0.0308   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 526      |
# |    ep_rew_mean        | 6.58     |
# | time/                 |          |
# |    fps                | 284      |
# |    iterations         | 4400     |
# |    time_elapsed       | 309      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -0.359   |
# |    explained_variance | 0.755    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.0361  |
# |    value_loss         | 0.0735   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 528       |
# |    ep_rew_mean        | 6.82      |
# | time/                 |           |
# |    fps                | 285       |
# |    iterations         | 4500      |
# |    time_elapsed       | 314       |
# |    total_timesteps    | 90000     |
# | train/                |           |
# |    entropy_loss       | -0.0194   |
# |    explained_variance | 0.455     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | -4.71e-05 |
# |    value_loss         | 0.241     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 534      |
# |    ep_rew_mean        | 6.97     |
# | time/                 |          |
# |    fps                | 286      |
# |    iterations         | 4600     |
# |    time_elapsed       | 320      |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -0.0964  |
# |    explained_variance | 0.979    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.00703 |
# |    value_loss         | 0.0253   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 538      |
# |    ep_rew_mean        | 7.13     |
# | time/                 |          |
# |    fps                | 287      |
# |    iterations         | 4700     |
# |    time_elapsed       | 326      |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -0.308   |
# |    explained_variance | 0.717    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.0452   |
# |    value_loss         | 0.194    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 543      |
# |    ep_rew_mean        | 7.31     |
# | time/                 |          |
# |    fps                | 288      |
# |    iterations         | 4800     |
# |    time_elapsed       | 332      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -0.089   |
# |    explained_variance | 0.912    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.00971 |
# |    value_loss         | 0.125    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 555      |
# |    ep_rew_mean        | 7.53     |
# | time/                 |          |
# |    fps                | 289      |
# |    iterations         | 4900     |
# |    time_elapsed       | 338      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -0.211   |
# |    explained_variance | 0.719    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.00071  |
# |    value_loss         | 0.102    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 546      |
# |    ep_rew_mean        | 7.35     |
# | time/                 |          |
# |    fps                | 290      |
# |    iterations         | 5000     |
# |    time_elapsed       | 344      |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -0.397   |
# |    explained_variance | 0.659    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | -0.0463  |
# |    value_loss         | 0.0458   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 543      |
# |    ep_rew_mean        | 7.17     |
# | time/                 |          |
# |    fps                | 291      |
# |    iterations         | 5100     |
# |    time_elapsed       | 350      |
# |    total_timesteps    | 102000   |
# | train/                |          |
# |    entropy_loss       | -0.228   |
# |    explained_variance | 0.933    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.0174  |
# |    value_loss         | 0.0434   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 535      |
# |    ep_rew_mean        | 7.01     |
# | time/                 |          |
# |    fps                | 291      |
# |    iterations         | 5200     |
# |    time_elapsed       | 356      |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -0.156   |
# |    explained_variance | 0.921    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.00733  |
# |    value_loss         | 0.0212   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 545      |
# |    ep_rew_mean        | 7.19     |
# | time/                 |          |
# |    fps                | 292      |
# |    iterations         | 5300     |
# |    time_elapsed       | 362      |
# |    total_timesteps    | 106000   |
# | train/                |          |
# |    entropy_loss       | -0.0467  |
# |    explained_variance | 0.969    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | 0.00159  |
# |    value_loss         | 0.0388   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 543      |
# |    ep_rew_mean        | 7.03     |
# | time/                 |          |
# |    fps                | 293      |
# |    iterations         | 5400     |
# |    time_elapsed       | 368      |
# |    total_timesteps    | 108000   |
# | train/                |          |
# |    entropy_loss       | -0.0581  |
# |    explained_variance | 0.92     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | -0.00145 |
# |    value_loss         | 0.0526   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 533      |
# |    ep_rew_mean        | 6.94     |
# | time/                 |          |
# |    fps                | 293      |
# |    iterations         | 5500     |
# |    time_elapsed       | 374      |
# |    total_timesteps    | 110000   |
# | train/                |          |
# |    entropy_loss       | -0.171   |
# |    explained_variance | 0.919    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | -0.00458 |
# |    value_loss         | 0.067    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 539      |
# |    ep_rew_mean        | 7.06     |
# | time/                 |          |
# |    fps                | 294      |
# |    iterations         | 5600     |
# |    time_elapsed       | 380      |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -0.315   |
# |    explained_variance | 0.74     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.0335   |
# |    value_loss         | 0.0658   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 539       |
# |    ep_rew_mean        | 7.05      |
# | time/                 |           |
# |    fps                | 295       |
# |    iterations         | 5700      |
# |    time_elapsed       | 386       |
# |    total_timesteps    | 114000    |
# | train/                |           |
# |    entropy_loss       | -0.0558   |
# |    explained_variance | 0.938     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | -0.000847 |
# |    value_loss         | 0.087     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 543      |
# |    ep_rew_mean        | 7.12     |
# | time/                 |          |
# |    fps                | 295      |
# |    iterations         | 5800     |
# |    time_elapsed       | 392      |
# |    total_timesteps    | 116000   |
# | train/                |          |
# |    entropy_loss       | -0.269   |
# |    explained_variance | 0.886    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.043    |
# |    value_loss         | 0.11     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 535      |
# |    ep_rew_mean        | 6.93     |
# | time/                 |          |
# |    fps                | 296      |
# |    iterations         | 5900     |
# |    time_elapsed       | 398      |
# |    total_timesteps    | 118000   |
# | train/                |          |
# |    entropy_loss       | -0.179   |
# |    explained_variance | 0.708    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.00376  |
# |    value_loss         | 0.271    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 537      |
# |    ep_rew_mean        | 6.91     |
# | time/                 |          |
# |    fps                | 297      |
# |    iterations         | 6000     |
# |    time_elapsed       | 403      |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -0.0683  |
# |    explained_variance | 0.939    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | -0.015   |
# |    value_loss         | 0.021    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 546      |
# |    ep_rew_mean        | 7.02     |
# | time/                 |          |
# |    fps                | 297      |
# |    iterations         | 6100     |
# |    time_elapsed       | 409      |
# |    total_timesteps    | 122000   |
# | train/                |          |
# |    entropy_loss       | -0.111   |
# |    explained_variance | 0.516    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -0.0178  |
# |    value_loss         | 0.204    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 543      |
# |    ep_rew_mean        | 6.94     |
# | time/                 |          |
# |    fps                | 298      |
# |    iterations         | 6200     |
# |    time_elapsed       | 415      |
# |    total_timesteps    | 124000   |
# | train/                |          |
# |    entropy_loss       | -0.213   |
# |    explained_variance | 0.933    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.0181  |
# |    value_loss         | 0.0316   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 548      |
# |    ep_rew_mean        | 7.1      |
# | time/                 |          |
# |    fps                | 298      |
# |    iterations         | 6300     |
# |    time_elapsed       | 421      |
# |    total_timesteps    | 126000   |
# | train/                |          |
# |    entropy_loss       | -0.28    |
# |    explained_variance | 0.325    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | -0.0178  |
# |    value_loss         | 0.178    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 557      |
# |    ep_rew_mean        | 7.28     |
# | time/                 |          |
# |    fps                | 299      |
# |    iterations         | 6400     |
# |    time_elapsed       | 427      |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -0.1     |
# |    explained_variance | 0.94     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | -0.0123  |
# |    value_loss         | 0.0955   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 559      |
# |    ep_rew_mean        | 7.35     |
# | time/                 |          |
# |    fps                | 299      |
# |    iterations         | 6500     |
# |    time_elapsed       | 433      |
# |    total_timesteps    | 130000   |
# | train/                |          |
# |    entropy_loss       | -0.0611  |
# |    explained_variance | 0.944    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | 0.00908  |
# |    value_loss         | 0.0938   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 563      |
# |    ep_rew_mean        | 7.48     |
# | time/                 |          |
# |    fps                | 300      |
# |    iterations         | 6600     |
# |    time_elapsed       | 439      |
# |    total_timesteps    | 132000   |
# | train/                |          |
# |    entropy_loss       | -0.0488  |
# |    explained_variance | 0.695    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.00603 |
# |    value_loss         | 0.16     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 563      |
# |    ep_rew_mean        | 7.49     |
# | time/                 |          |
# |    fps                | 300      |
# |    iterations         | 6700     |
# |    time_elapsed       | 445      |
# |    total_timesteps    | 134000   |
# | train/                |          |
# |    entropy_loss       | -0.0769  |
# |    explained_variance | 0.863    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -0.0108  |
# |    value_loss         | 0.15     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 565      |
# |    ep_rew_mean        | 7.54     |
# | time/                 |          |
# |    fps                | 301      |
# |    iterations         | 6800     |
# |    time_elapsed       | 451      |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -0.146   |
# |    explained_variance | 0.947    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | -0.00493 |
# |    value_loss         | 0.0314   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 559      |
# |    ep_rew_mean        | 7.4      |
# | time/                 |          |
# |    fps                | 301      |
# |    iterations         | 6900     |
# |    time_elapsed       | 457      |
# |    total_timesteps    | 138000   |
# | train/                |          |
# |    entropy_loss       | -0.171   |
# |    explained_variance | 0.465    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | -0.00126 |
# |    value_loss         | 0.279    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 553      |
# |    ep_rew_mean        | 7.35     |
# | time/                 |          |
# |    fps                | 302      |
# |    iterations         | 7000     |
# |    time_elapsed       | 463      |
# |    total_timesteps    | 140000   |
# | train/                |          |
# |    entropy_loss       | -0.0843  |
# |    explained_variance | 0.914    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | 0.00706  |
# |    value_loss         | 0.0231   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 560      |
# |    ep_rew_mean        | 7.47     |
# | time/                 |          |
# |    fps                | 302      |
# |    iterations         | 7100     |
# |    time_elapsed       | 469      |
# |    total_timesteps    | 142000   |
# | train/                |          |
# |    entropy_loss       | -0.165   |
# |    explained_variance | 0.854    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | -0.0148  |
# |    value_loss         | 0.0602   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 557      |
# |    ep_rew_mean        | 7.41     |
# | time/                 |          |
# |    fps                | 302      |
# |    iterations         | 7200     |
# |    time_elapsed       | 475      |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | -0.0399  |
# |    explained_variance | 0.951    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | 0.00233  |
# |    value_loss         | 0.024    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 557      |
# |    ep_rew_mean        | 7.35     |
# | time/                 |          |
# |    fps                | 303      |
# |    iterations         | 7300     |
# |    time_elapsed       | 481      |
# |    total_timesteps    | 146000   |
# | train/                |          |
# |    entropy_loss       | -0.103   |
# |    explained_variance | 0.81     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | 0.0189   |
# |    value_loss         | 0.0816   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 555      |
# |    ep_rew_mean        | 7.32     |
# | time/                 |          |
# |    fps                | 303      |
# |    iterations         | 7400     |
# |    time_elapsed       | 487      |
# |    total_timesteps    | 148000   |
# | train/                |          |
# |    entropy_loss       | -0.0753  |
# |    explained_variance | 0.759    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | 0.151    |
# |    value_loss         | 0.154    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 570      |
# |    ep_rew_mean        | 7.72     |
# | time/                 |          |
# |    fps                | 303      |
# |    iterations         | 7500     |
# |    time_elapsed       | 493      |
# |    total_timesteps    | 150000   |
# | train/                |          |
# |    entropy_loss       | -0.046   |
# |    explained_variance | 0.938    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | 0.00125  |
# |    value_loss         | 0.0496   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 566      |
# |    ep_rew_mean        | 7.54     |
# | time/                 |          |
# |    fps                | 304      |
# |    iterations         | 7600     |
# |    time_elapsed       | 499      |
# |    total_timesteps    | 152000   |
# | train/                |          |
# |    entropy_loss       | -0.257   |
# |    explained_variance | 0.968    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | -0.0347  |
# |    value_loss         | 0.0519   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 572      |
# ...
# |    explained_variance | 0.764    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17499    |
# |    policy_loss        | -0.002   |
# |    value_loss         | 0.0559   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 705      |
# |    ep_rew_mean        | 10.5     |
# | time/                 |          |
# |    fps                | 316      |
# |    iterations         | 17600    |
# |    time_elapsed       | 1111     |
# |    total_timesteps    | 352000   |
# | train/                |          |
# |    entropy_loss       | -0.0752  |
# |    explained_variance | 0.84     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17599    |
# |    policy_loss        | -0.00265 |
# |    value_loss         | 0.0327   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 712      |
# |    ep_rew_mean        | 10.7     |
# | time/                 |          |
# |    fps                | 316      |
# |    iterations         | 17700    |
# |    time_elapsed       | 1118     |
# |    total_timesteps    | 354000   |
# | train/                |          |
# |    entropy_loss       | -0.0654  |
# |    explained_variance | 0.912    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17699    |
# |    policy_loss        | -0.0033  |
# |    value_loss         | 0.0635   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 716      |
# |    ep_rew_mean        | 10.8     |
# | time/                 |          |
# |    fps                | 316      |
# |    iterations         | 17800    |
# |    time_elapsed       | 1125     |
# |    total_timesteps    | 356000   |
# | train/                |          |
# |    entropy_loss       | -0.112   |
# |    explained_variance | 0.173    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17799    |
# |    policy_loss        | 0.013    |
# |    value_loss         | 0.412    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 723      |
# |    ep_rew_mean        | 11       |
# | time/                 |          |
# |    fps                | 315      |
# |    iterations         | 17900    |
# |    time_elapsed       | 1132     |
# |    total_timesteps    | 358000   |
# | train/                |          |
# |    entropy_loss       | -0.0958  |
# |    explained_variance | 0.901    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17899    |
# |    policy_loss        | 0.0035   |
# |    value_loss         | 0.103    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 735       |
# |    ep_rew_mean        | 11.4      |
# | time/                 |           |
# |    fps                | 315       |
# |    iterations         | 18000     |
# |    time_elapsed       | 1139      |
# |    total_timesteps    | 360000    |
# | train/                |           |
# |    entropy_loss       | -0.00975  |
# |    explained_variance | 0.828     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17999     |
# |    policy_loss        | -0.000531 |
# |    value_loss         | 0.375     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 730      |
# |    ep_rew_mean        | 11.4     |
# | time/                 |          |
# |    fps                | 315      |
# |    iterations         | 18100    |
# |    time_elapsed       | 1147     |
# |    total_timesteps    | 362000   |
# | train/                |          |
# |    entropy_loss       | -0.0154  |
# |    explained_variance | 0.785    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18099    |
# |    policy_loss        | 0.000874 |
# |    value_loss         | 0.031    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 738      |
# |    ep_rew_mean        | 11.7     |
# | time/                 |          |
# |    fps                | 315      |
# |    iterations         | 18200    |
# |    time_elapsed       | 1154     |
# |    total_timesteps    | 364000   |
# | train/                |          |
# |    entropy_loss       | -0.0556  |
# |    explained_variance | 0.589    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18199    |
# |    policy_loss        | -0.00448 |
# |    value_loss         | 0.126    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 732      |
# |    ep_rew_mean        | 11.7     |
# | time/                 |          |
# |    fps                | 315      |
# |    iterations         | 18300    |
# |    time_elapsed       | 1161     |
# |    total_timesteps    | 366000   |
# | train/                |          |
# |    entropy_loss       | -0.0609  |
# |    explained_variance | 0.673    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18299    |
# |    policy_loss        | 0.02     |
# |    value_loss         | 0.281    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 738      |
# |    ep_rew_mean        | 12.1     |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 18400    |
# |    time_elapsed       | 1168     |
# |    total_timesteps    | 368000   |
# | train/                |          |
# |    entropy_loss       | -0.128   |
# |    explained_variance | 0.942    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18399    |
# |    policy_loss        | -0.00283 |
# |    value_loss         | 0.0967   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 743      |
# |    ep_rew_mean        | 12.2     |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 18500    |
# |    time_elapsed       | 1175     |
# |    total_timesteps    | 370000   |
# | train/                |          |
# |    entropy_loss       | -0.0649  |
# |    explained_variance | 0.946    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18499    |
# |    policy_loss        | 0.000663 |
# |    value_loss         | 0.0742   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 735      |
# |    ep_rew_mean        | 12.3     |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 18600    |
# |    time_elapsed       | 1182     |
# |    total_timesteps    | 372000   |
# | train/                |          |
# |    entropy_loss       | -0.231   |
# |    explained_variance | 0.932    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18599    |
# |    policy_loss        | -0.125   |
# |    value_loss         | 0.175    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 731      |
# |    ep_rew_mean        | 12       |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 18700    |
# |    time_elapsed       | 1189     |
# |    total_timesteps    | 374000   |
# | train/                |          |
# |    entropy_loss       | -0.0456  |
# |    explained_variance | 0.48     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18699    |
# |    policy_loss        | -0.0152  |
# |    value_loss         | 0.166    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 728      |
# |    ep_rew_mean        | 12       |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 18800    |
# |    time_elapsed       | 1195     |
# |    total_timesteps    | 376000   |
# | train/                |          |
# |    entropy_loss       | -0.0452  |
# |    explained_variance | 0.904    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18799    |
# |    policy_loss        | -0.0526  |
# |    value_loss         | 0.0674   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 724      |
# |    ep_rew_mean        | 11.6     |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 18900    |
# |    time_elapsed       | 1201     |
# |    total_timesteps    | 378000   |
# | train/                |          |
# |    entropy_loss       | -0.173   |
# |    explained_variance | -0.102   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18899    |
# |    policy_loss        | 0.385    |
# |    value_loss         | 0.544    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 717      |
# |    ep_rew_mean        | 11.3     |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 19000    |
# |    time_elapsed       | 1207     |
# |    total_timesteps    | 380000   |
# | train/                |          |
# |    entropy_loss       | -0.014   |
# |    explained_variance | 0.834    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18999    |
# |    policy_loss        | 0.000867 |
# |    value_loss         | 0.115    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 724      |
# |    ep_rew_mean        | 11.5     |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 19100    |
# |    time_elapsed       | 1214     |
# |    total_timesteps    | 382000   |
# | train/                |          |
# |    entropy_loss       | -0.113   |
# |    explained_variance | 0.926    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19099    |
# |    policy_loss        | -0.0557  |
# |    value_loss         | 0.0904   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 716      |
# |    ep_rew_mean        | 11.2     |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 19200    |
# |    time_elapsed       | 1221     |
# |    total_timesteps    | 384000   |
# | train/                |          |
# |    entropy_loss       | -0.0809  |
# |    explained_variance | 0.684    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19199    |
# |    policy_loss        | -0.0115  |
# |    value_loss         | 0.0789   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 705      |
# |    ep_rew_mean        | 10.9     |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 19300    |
# |    time_elapsed       | 1227     |
# |    total_timesteps    | 386000   |
# | train/                |          |
# |    entropy_loss       | -0.126   |
# |    explained_variance | 0.836    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19299    |
# |    policy_loss        | -0.0352  |
# |    value_loss         | 0.294    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 692      |
# |    ep_rew_mean        | 10.5     |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 19400    |
# |    time_elapsed       | 1233     |
# |    total_timesteps    | 388000   |
# | train/                |          |
# |    entropy_loss       | -0.0117  |
# |    explained_variance | 0.897    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19399    |
# |    policy_loss        | -0.00149 |
# |    value_loss         | 0.0942   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 696      |
# |    ep_rew_mean        | 10.8     |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 19500    |
# |    time_elapsed       | 1240     |
# |    total_timesteps    | 390000   |
# | train/                |          |
# |    entropy_loss       | -0.0955  |
# |    explained_variance | 0.483    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19499    |
# |    policy_loss        | 0.154    |
# |    value_loss         | 0.25     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 695       |
# |    ep_rew_mean        | 10.9      |
# | time/                 |           |
# |    fps                | 314       |
# |    iterations         | 19600     |
# |    time_elapsed       | 1246      |
# |    total_timesteps    | 392000    |
# | train/                |           |
# |    entropy_loss       | -0.0291   |
# |    explained_variance | 0.898     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19599     |
# |    policy_loss        | -0.000838 |
# |    value_loss         | 0.0608    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 694      |
# |    ep_rew_mean        | 10.9     |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 19700    |
# |    time_elapsed       | 1253     |
# |    total_timesteps    | 394000   |
# | train/                |          |
# |    entropy_loss       | -0.0489  |
# |    explained_variance | 0.181    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19699    |
# |    policy_loss        | 0.0125   |
# |    value_loss         | 0.146    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 697      |
# |    ep_rew_mean        | 11.1     |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 19800    |
# |    time_elapsed       | 1259     |
# |    total_timesteps    | 396000   |
# | train/                |          |
# |    entropy_loss       | -0.0939  |
# |    explained_variance | 0.653    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19799    |
# |    policy_loss        | 0.00132  |
# |    value_loss         | 0.0758   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 698      |
# |    ep_rew_mean        | 11.3     |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 19900    |
# |    time_elapsed       | 1266     |
# |    total_timesteps    | 398000   |
# | train/                |          |
# |    entropy_loss       | -0.0703  |
# |    explained_variance | 0.395    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19899    |
# |    policy_loss        | -0.0313  |
# |    value_loss         | 0.332    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 688      |
# |    ep_rew_mean        | 11.2     |
# | time/                 |          |
# |    fps                | 314      |
# |    iterations         | 20000    |
# |    time_elapsed       | 1273     |
# |    total_timesteps    | 400000   |
# | train/                |          |
# |    entropy_loss       | -0.101   |
# |    explained_variance | 0.844    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19999    |
# |    policy_loss        | 0.0017   |
# |    value_loss         | 0.0159   |
# ------------------------------------

# %% [markdown]
# # 4. Save and Reload Model

# %%
a2c_path = os.path.join('Training', 'Saved Models', 'A2C_model')

# %%
model.save(a2c_path)

# %%
del model

# %%
env = make_atari_env('Breakout-v0', n_envs=1, seed=0)
env = VecFrameStack(env, n_stack=4)

# %%
model = A2C.load(a2c_path, env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# # 5. Evaluate and Test

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# (12.9, 3.419064199455752)

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
# Out:
# ------------------------------------------------------------------------
# KeyboardInterrupt                      Traceback (most recent call last)
# <ipython-input-32-c9313fcdef63> in <module>
#       3     action, _states = model.predict(obs)
#       4     obs, rewards, dones, info = env.step(action)
# ----> 5     env.render()
#
# ~/anaconda3/envs/rl/lib/python3.8/site-packages/stable_baselines3/common/vec_env/base_vec_env.py in render(self, mode)
#     279
#     280     def render(self, mode: str = "human") -> Optional[np.ndarray]:
# --> 281         return self.venv.render(mode=mode)
#     282
#     283     def get_images(self) -> Sequence[np.ndarray]:
#
# ~/anaconda3/envs/rl/lib/python3.8/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py in render(self, mode)
#      83         """
#      84         if self.num_envs == 1:
# ---> 85             return self.envs[0].render(mode=mode)
#      86         else:
#      87             return super().render(mode=mode)
#
# ~/anaconda3/envs/rl/lib/python3.8/site-packages/gym/core.py in render(self, mode, **kwargs)
#     238
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#     242     def close(self):
#
# ~/anaconda3/envs/rl/lib/python3.8/site-packages/gym/core.py in render(self, mode, **kwargs)
#     238
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#     242     def close(self):
#
# ~/anaconda3/envs/rl/lib/python3.8/site-packages/gym/core.py in render(self, mode, **kwargs)
#     238
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#     242     def close(self):
#
# ~/anaconda3/envs/rl/lib/python3.8/site-packages/gym/core.py in render(self, mode, **kwargs)
#     238
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#     242     def close(self):
#
# ~/anaconda3/envs/rl/lib/python3.8/site-packages/gym/core.py in render(self, mode, **kwargs)
#     238
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#     242     def close(self):
#
# ~/anaconda3/envs/rl/lib/python3.8/site-packages/gym/core.py in render(self, mode, **kwargs)
#     238
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#     242     def close(self):
#
# ~/anaconda3/envs/rl/lib/python3.8/site-packages/gym/core.py in render(self, mode, **kwargs)
#     238
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#     242     def close(self):
#
# ~/anaconda3/envs/rl/lib/python3.8/site-packages/gym/core.py in render(self, mode, **kwargs)
#     238
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#     242     def close(self):
#
# ~/anaconda3/envs/rl/lib/python3.8/site-packages/gym/core.py in render(self, mode, **kwargs)
#     238
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#     242     def close(self):
#
# ~/anaconda3/envs/rl/lib/python3.8/site-packages/gym/envs/atari/atari_env.py in render(self, mode)
#     153             if self.viewer is None:
#     154                 self.viewer = rendering.SimpleImageViewer()
# --> 155             self.viewer.imshow(img)
#     156             return self.viewer.isopen
#     157
#
# ~/anaconda3/envs/rl/lib/python3.8/site-packages/gym/envs/classic_control/rendering.py in imshow(self, arr)
#     372         self.window.dispatch_events()
#     373         texture.blit(0, 0) # draw
# --> 374         self.window.flip()
#     375     def close(self):
#     376         if self.isopen and sys.meta_path:
#
# ~/anaconda3/envs/rl/lib/python3.8/site-packages/pyglet/window/xlib/__init__.py in flip(self)
#     529         # TODO canvas.flip?
#     530         if self.context:
# --> 531             self.context.flip()
#     532
#     533         self._sync_resize()
#
# ~/anaconda3/envs/rl/lib/python3.8/site-packages/pyglet/gl/xlib.py in flip(self)
#     374         if self._vsync:
#     375             self._wait_vsync()
# --> 376         glx.glXSwapBuffers(self.x_display, self.glx_window)
#     377
#     378
#
# KeyboardInterrupt:

# %%
env.close()
