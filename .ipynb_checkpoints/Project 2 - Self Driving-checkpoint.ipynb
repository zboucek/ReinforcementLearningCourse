# %% [markdown]
# # 1. Import Dependencies

# %%
#Install SWIG https://sourceforge.net/projects/swig/files/swigwin/swigwin-4.0.2/swigwin-4.0.2.zip/download?use_mirror=ixpeering

# %%
# !pip install gym[box2d] pyglet==1.3.2
# Out:
# Requirement already satisfied: gym[box2d] in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (0.18.3)
# Collecting pyglet==1.3.2
#   Downloading pyglet-1.3.2-py2.py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 7.7 MB/s eta 0:00:01
# Requirement already satisfied: future in /home/zboucek/.local/lib/python3.8/site-packages (from pyglet==1.3.2) (0.18.2)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from gym[box2d]) (1.6.0)
# Requirement already satisfied: scipy in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from gym[box2d]) (1.6.3)
# Requirement already satisfied: numpy>=1.10.4 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from gym[box2d]) (1.18.5)
# Requirement already satisfied: Pillow<=8.2.0 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from gym[box2d]) (8.2.0)
# Collecting gym[box2d]
#   Using cached gym-0.18.0-py3-none-any.whl
#   Using cached gym-0.17.3.tar.gz (1.6 MB)
#   Downloading gym-0.17.2.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 29.8 MB/s eta 0:00:01
#   Downloading gym-0.17.1.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 53.1 MB/s eta 0:00:01
# Requirement already satisfied: six in /home/zboucek/.local/lib/python3.8/site-packages (from gym[box2d]) (1.15.0)
#   Downloading gym-0.17.0.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 92.1 MB/s eta 0:00:01
#   Downloading gym-0.16.0.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 107.5 MB/s eta 0:00:01
#   Downloading gym-0.15.7.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 93.5 MB/s eta 0:00:01
#   Downloading gym-0.15.6.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 122.9 MB/s eta 0:00:01
#   Downloading gym-0.15.4.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 99.6 MB/s eta 0:00:01
# Collecting cloudpickle~=1.2.0
#   Downloading cloudpickle-1.2.2-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: opencv-python in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from gym[box2d]) (4.5.2.52)
# Collecting box2d-py~=2.3.5
#   Downloading box2d-py-2.3.8.tar.gz (374 kB)
#      |████████████████████████████████| 374 kB 120.2 MB/s eta 0:00:01
# Building wheels for collected packages: gym, box2d-py
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.15.4-py3-none-any.whl size=1648484 sha256=5283b55d974926352a2de663b36d170162a4f630eb9d32bf1836ebf463e060e7
#   Stored in directory: /home/zboucek/.cache/pip/wheels/9c/18/7d/c8a0742c313735e23335fa606ce951d9510ed4f12af2cb763b
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.8-cp38-cp38-linux_x86_64.whl size=3081898 sha256=a66e59df29f4bcc6c9517ffa5ffee25051b6d65ccc53416936ceb5122315315f
#   Stored in directory: /home/zboucek/.cache/pip/wheels/cc/4f/d6/44eb0a9e6fea384e58f19cb0c4125e46a23af2b33fe3a7e81c
# Successfully built gym box2d-py
# Installing collected packages: pyglet, cloudpickle, gym, box2d-py
#   Attempting uninstall: pyglet
#     Found existing installation: pyglet 1.5.15
#     Uninstalling pyglet-1.5.15:
#       Successfully uninstalled pyglet-1.5.15
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.6.0
#     Uninstalling cloudpickle-1.6.0:
#       Successfully uninstalled cloudpickle-1.6.0
#   Attempting uninstall: gym
#     Found existing installation: gym 0.18.3
#     Uninstalling gym-0.18.3:
#       Successfully uninstalled gym-0.18.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# stable-baselines3 1.1.0 requires gym>=0.17, but you have gym 0.15.4 which is incompatible.
# Successfully installed box2d-py-2.3.8 cloudpickle-1.2.2 gym-0.15.4 pyglet-1.3.2

# %%
import gym 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %% [markdown]
# # 2. Test Environment

# %%
environment_name = "CarRacing-v0"

# %%
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Track generation: 1005..1262 -> 257-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1056..1325 -> 269-tiles track
# Episode:1 Score:-25.373134328358507
# Track generation: 1242..1565 -> 323-tiles track
# Episode:2 Score:-37.8881987577646
# Track generation: 1203..1508 -> 305-tiles track
# Episode:3 Score:-34.210526315789956
# Track generation: 1124..1414 -> 290-tiles track
# Episode:4 Score:-30.795847750865555
# Track generation: 1240..1552 -> 312-tiles track
# Episode:5 Score:-38.90675241157616

# %%
env.close()

# %%
env.action_space.sample()
# Out:
# array([-0.7524259,  0.4226909,  0.044053 ], dtype=float32)

# %%
env.observation_space.sample()
# Out:
# array([[[240,  61, 176],
#         [ 13,  57, 222],
#         [227,  83,  60],
#         ...,
#         [ 65, 197,  72],
#         [197, 243,  11],
#         [ 10,   7,  21]],
#
#        [[206, 166, 138],
#         [ 19, 115, 183],
#         [252, 138, 223],
#         ...,
#         [  3,  19,  75],
#         [  4, 190,   6],
#         [ 47,  37,  24]],
#
#        [[214, 250, 175],
#         [219,  69,  77],
#         [ 35, 175, 232],
#         ...,
#         [134, 238, 196],
#         [ 82,  49, 216],
#         [ 30,  90, 140]],
#
#        ...,
#
#        [[163,  71,  54],
#         [ 13, 173, 124],
#         [222,  57, 193],
#         ...,
#         [171, 159,  56],
#         [ 48, 180, 209],
#         [154, 101,  43]],
#
#        [[192, 139,  91],
#         [ 88,  98,  80],
#         [ 35, 208, 167],
#         ...,
#         [111,  80, 176],
#         [197, 243, 208],
#         [ 18, 241, 205]],
#
#        [[ 32, 218,  62],
#         [198, 130, 165],
#         [ 86,   0,  99],
#         ...,
#         [ 75,   5, 134],
#         [  3,   7,  55],
#         [ 78, 175,  83]]], dtype=uint8)

# %% [markdown]
# # 3. Train Model

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=40000)
# Out:
# Track generation: 1329..1665 -> 336-tiles track
# Logging to Training/Logs/PPO_3
# Track generation: 1136..1424 -> 288-tiles track
# Track generation: 1190..1498 -> 308-tiles track
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -62.7    |
# | time/              |          |
# |    fps             | 62       |
# |    iterations      | 1        |
# |    time_elapsed    | 32       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Track generation: 1272..1594 -> 322-tiles track
# Track generation: 1123..1408 -> 285-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -59         |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 2           |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.004799568 |
# |    clip_fraction        | 0.0595      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | -0.00594    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.202       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00524    |
# |    std                  | 1           |
# |    value_loss           | 0.52        |
# -----------------------------------------
# Track generation: 1068..1339 -> 271-tiles track
# Track generation: 1116..1399 -> 283-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -56.4      |
# | time/                   |            |
# |    fps                  | 61         |
# |    iterations           | 3          |
# |    time_elapsed         | 100        |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01140791 |
# |    clip_fraction        | 0.081      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.25      |
# |    explained_variance   | 0.144      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.122      |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00777   |
# |    std                  | 0.994      |
# |    value_loss           | 0.475      |
# ----------------------------------------
# Track generation: 1173..1479 -> 306-tiles track
# Track generation: 1165..1469 -> 304-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -53.7       |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 4           |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012862648 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.126       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.309       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.985       |
# |    value_loss           | 0.572       |
# -----------------------------------------
# Track generation: 1200..1504 -> 304-tiles track
# Track generation: 992..1244 -> 252-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52         |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 5           |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010523645 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.111       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0158     |
# |    std                  | 0.975       |
# |    value_loss           | 0.471       |
# -----------------------------------------
# Track generation: 987..1246 -> 259-tiles track
# Track generation: 1111..1393 -> 282-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -51.2       |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 6           |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010962773 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.11        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0167     |
# |    std                  | 0.975       |
# |    value_loss           | 0.434       |
# -----------------------------------------
# Track generation: 1096..1363 -> 267-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1133..1427 -> 294-tiles track
# Track generation: 1107..1387 -> 280-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -50.7       |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 7           |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.014261421 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.369       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0408      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0219     |
# |    std                  | 0.972       |
# |    value_loss           | 0.486       |
# -----------------------------------------
# Track generation: 1216..1524 -> 308-tiles track
# Track generation: 1218..1527 -> 309-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -50.4       |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 8           |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.020263858 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.326       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.204       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0279     |
# |    std                  | 0.96        |
# |    value_loss           | 0.373       |
# -----------------------------------------
# Track generation: 1335..1673 -> 338-tiles track
# Track generation: 1126..1418 -> 292-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -50.3       |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 9           |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.026513912 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | 0.3         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00907    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0326     |
# |    std                  | 0.959       |
# |    value_loss           | 0.308       |
# -----------------------------------------
# Track generation: 1197..1508 -> 311-tiles track
# Track generation: 1081..1355 -> 274-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49.7       |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 10          |
# |    time_elapsed         | 329         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.024750711 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | 0.277       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0543      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0335     |
# |    std                  | 0.951       |
# |    value_loss           | 0.274       |
# -----------------------------------------
# Track generation: 1149..1441 -> 292-tiles track
# Track generation: 1166..1468 -> 302-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -50.3       |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 11          |
# |    time_elapsed         | 363         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.013836661 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | 0.13        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.129       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0176     |
# |    std                  | 0.943       |
# |    value_loss           | 0.353       |
# -----------------------------------------
# Track generation: 1090..1371 -> 281-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1276..1599 -> 323-tiles track
# Track generation: 1178..1476 -> 298-tiles track
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -49.7     |
# | time/                   |           |
# |    fps                  | 61        |
# |    iterations           | 12        |
# |    time_elapsed         | 397       |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0259057 |
# |    clip_fraction        | 0.228     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.05     |
# |    explained_variance   | 0.468     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0347    |
# |    n_updates            | 110       |
# |    policy_gradient_loss | -0.0332   |
# |    std                  | 0.926     |
# |    value_loss           | 0.234     |
# ---------------------------------------
# Track generation: 1052..1326 -> 274-tiles track
# Track generation: 1152..1444 -> 292-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -50         |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 13          |
# |    time_elapsed         | 430         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.038347095 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.01       |
# |    explained_variance   | 0.573       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00677    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0367     |
# |    std                  | 0.917       |
# |    value_loss           | 0.198       |
# -----------------------------------------
# Track generation: 1140..1429 -> 289-tiles track
# Track generation: 1373..1720 -> 347-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -48.8      |
# | time/                   |            |
# |    fps                  | 61         |
# |    iterations           | 14         |
# |    time_elapsed         | 465        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.03131575 |
# |    clip_fraction        | 0.253      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.97      |
# |    explained_variance   | 0.494      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00852    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0342    |
# |    std                  | 0.907      |
# |    value_loss           | 0.203      |
# ----------------------------------------
# Track generation: 1004..1259 -> 255-tiles track
# Track generation: 1211..1518 -> 307-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -49.4      |
# | time/                   |            |
# |    fps                  | 61         |
# |    iterations           | 15         |
# |    time_elapsed         | 499        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.03403553 |
# |    clip_fraction        | 0.297      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.94      |
# |    explained_variance   | 0.652      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0496    |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0398    |
# |    std                  | 0.898      |
# |    value_loss           | 0.203      |
# ----------------------------------------
# Track generation: 1257..1585 -> 328-tiles track
# Track generation: 1181..1480 -> 299-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49.2       |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 16          |
# |    time_elapsed         | 535         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.032361314 |
# |    clip_fraction        | 0.286       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.91       |
# |    explained_variance   | 0.622       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0121     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0323     |
# |    std                  | 0.892       |
# |    value_loss           | 0.227       |
# -----------------------------------------
# Track generation: 1364..1709 -> 345-tiles track
# Track generation: 1017..1275 -> 258-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 17          |
# |    time_elapsed         | 571         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.029428527 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.89       |
# |    explained_variance   | 0.755       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00636     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0317     |
# |    std                  | 0.882       |
# |    value_loss           | 0.308       |
# -----------------------------------------
# Track generation: 1151..1443 -> 292-tiles track
# Track generation: 1155..1448 -> 293-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -48.6      |
# | time/                   |            |
# |    fps                  | 60         |
# |    iterations           | 18         |
# |    time_elapsed         | 605        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.05112113 |
# |    clip_fraction        | 0.351      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.85      |
# |    explained_variance   | 0.739      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0252    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0429    |
# |    std                  | 0.869      |
# |    value_loss           | 0.199      |
# ----------------------------------------
# Track generation: 979..1228 -> 249-tiles track
# Track generation: 1420..1779 -> 359-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -47        |
# | time/                   |            |
# |    fps                  | 60         |
# |    iterations           | 19         |
# |    time_elapsed         | 640        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.05065705 |
# |    clip_fraction        | 0.338      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.79      |
# |    explained_variance   | 0.728      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.029     |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0434    |
# |    std                  | 0.851      |
# |    value_loss           | 0.235      |
# ----------------------------------------
# Track generation: 1004..1259 -> 255-tiles track
# Track generation: 1164..1459 -> 295-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -46         |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 20          |
# |    time_elapsed         | 674         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.060480077 |
# |    clip_fraction        | 0.366       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.74       |
# |    explained_variance   | 0.535       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0495     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0463     |
# |    std                  | 0.836       |
# |    value_loss           | 0.219       |
# -----------------------------------------

# %% [markdown]
# # 4. Save Model

# %%
ppo_path = os.path.join('Training', 'Saved Models', 'PPO_Driving_model')

# %%
model.save(ppo_path)

# %% [markdown]
# # 5. Evaluate and Test

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Track generation: 1090..1367 -> 277-tiles track
# Track generation: 1114..1397 -> 283-tiles track
# Track generation: 1039..1303 -> 264-tiles track
# Track generation: 1232..1544 -> 312-tiles track
# Track generation: 1093..1378 -> 285-tiles track
# Track generation: 1189..1491 -> 302-tiles track
# Track generation: 1149..1439 -> 290-tiles track
# Track generation: 1171..1468 -> 297-tiles track
# Track generation: 1174..1477 -> 303-tiles track
# Track generation: 1227..1538 -> 311-tiles track
# Track generation: 1171..1468 -> 297-tiles track
# (-28.024090682715176, 43.19714903698551)

# %%
env.close()

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
# Out:
# Track generation: 1237..1551 -> 314-tiles track
# ---------------------------------------------------------
# ValueError              Traceback (most recent call last)
# <ipython-input-19-c9313fcdef63> in <module>
#       1 obs = env.reset()
#       2 while True:
# ----> 3     action, _states = model.predict(obs)
#       4     obs, rewards, dones, info = env.step(action)
#       5     env.render()
#
# ~/anaconda3/envs/rl/lib/python3.8/site-packages/stable_baselines3/common/base_class.py in predict(self, observation, state, mask, deterministic)
#     537             (used in recurrent policies)
#     538         """
# --> 539         return self.policy.predict(observation, state, mask, deterministic)
#     540
#     541     def set_random_seed(self, seed: Optional[int] = None) -> None:
#
# ~/anaconda3/envs/rl/lib/python3.8/site-packages/stable_baselines3/common/policies.py in predict(self, observation, state, mask, deterministic)
#     297             observation = observation.reshape((-1,) + self.observation_space.shape)
#     298
# --> 299         observation = obs_as_tensor(observation, self.device)
#     300
#     301         with th.no_grad():
#
# ~/anaconda3/envs/rl/lib/python3.8/site-packages/stable_baselines3/common/utils.py in obs_as_tensor(obs, device)
#     429     """
#     430     if isinstance(obs, np.ndarray):
# --> 431         return th.as_tensor(obs).to(device)
#     432     elif isinstance(obs, dict):
#     433         return {key: th.as_tensor(_obs).to(device) for (key, _obs) in obs.items()}
#
# ValueError: At least one stride in the given numpy array is negative, and tensors with negative strides are not currently supported. (You can probably work around this by making a copy of your array  with array.copy().)

# %%
env.close()
