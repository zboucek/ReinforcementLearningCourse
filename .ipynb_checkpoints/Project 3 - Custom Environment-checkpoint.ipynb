# %%
#https://sourceforge.net/projects/swig/files/swigwin/swigwin-4.0.2/swigwin-4.0.2.zip/download?use_mirror=ixpeering

# %% [markdown]
# # 1. Import Dependencies

# %%
import gym
from gym import Env
from gym.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete
import numpy as np
import random
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Types of Spaces

# %%
Discrete(3)
# Out:
# Discrete(3)

# %%
Box(0,1,shape=(3,3)).sample()
# Out:
# array([[0.84952307, 0.1365212 , 0.94041765],
#        [0.3065854 , 0.9095639 , 0.745812  ],
#        [0.61863256, 0.22895272, 0.01947667]], dtype=float32)

# %%
Box(0,255,shape=(3,3), dtype=int).sample()
# Out:
# array([[ 21, 224,  56],
#        [115,  98, 201],
#        [  9, 223, 142]])

# %%
Tuple((Discrete(2), Box(0,100, shape=(1,)))).sample()
# Out:
# (1, array([84.50369], dtype=float32))

# %%
Dict({'height':Discrete(2), "speed":Box(0,100, shape=(1,))}).sample()
# Out:
# OrderedDict([('height', 0), ('speed', array([38.907375], dtype=float32))])

# %%
MultiBinary(4).sample()
# Out:
# array([1, 1, 0, 1], dtype=int8)

# %%
MultiDiscrete([5,2,2]).sample()
# Out:
# array([0, 1, 0])

# %% [markdown]
# # 3. Building an Environment

# %%
class ShowerEnv(Env):
    def __init__(self):
        # Actions we can take, down, stay, up
        self.action_space = Discrete(3)
        # Temperature array
        self.observation_space = Box(low=np.array([0]), high=np.array([100]))
        # Set start temp
        self.state = 38 + random.randint(-3,3)
        # Set shower length
        self.shower_length = 60
        
    def step(self, action):
        # Apply action
        # 0 -1 = -1 temperature
        # 1 -1 = 0 
        # 2 -1 = 1 temperature 
        self.state += action -1 
        # Reduce shower length by 1 second
        self.shower_length -= 1 
        
        # Calculate reward
        if self.state >=37 and self.state <=39: 
            reward =1 
        else: 
            reward = -1 
        
        # Check if shower is done
        if self.shower_length <= 0: 
            done = True
        else:
            done = False
        
        # Apply temperature noise
        #self.state += random.randint(-1,1)
        # Set placeholder for info
        info = {}
        
        # Return step information
        return self.state, reward, done, info

    def render(self):
        # Implement viz
        pass
    
    def reset(self):
        # Reset shower temperature
        self.state = np.array([38 + random.randint(-3,3)]).astype(float)
        # Reset shower time
        self.shower_length = 60 
        return self.state

# %%
env=ShowerEnv()

# %%
env.observation_space.sample()
# Out:
# array([89.25364], dtype=float32)

# %%
env.reset()
# Out:
# array([39.])

# %%
from stable_baselines3.common.env_checker import check_env

# %%
check_env(env, warn=True)

# %% [markdown]
# # 4. Test Environment

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:-52
# Episode:2 Score:-14
# Episode:3 Score:-46
# Episode:4 Score:-20
# Episode:5 Score:-4

# %%
env.close()

# %% [markdown]
# # 5. Train Model

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=400000)
# Out:
# Logging to Training/Logs/PPO_5
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | -23.2    |
# | time/              |          |
# |    fps             | 3069     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -26.7        |
# | time/                   |              |
# |    fps                  | 2072         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0102413865 |
# |    clip_fraction        | 0.0546       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.000214    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.5         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00378     |
# |    value_loss           | 58.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -26          |
# | time/                   |              |
# |    fps                  | 1871         |
# |    iterations           | 3            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0035964875 |
# |    clip_fraction        | 0.0544       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.00138     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.1         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00306     |
# |    value_loss           | 61.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -28          |
# | time/                   |              |
# |    fps                  | 1787         |
# |    iterations           | 4            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0027817143 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.000144     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.8         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00266     |
# |    value_loss           | 61.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -26.2       |
# | time/                   |             |
# |    fps                  | 1749        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008557335 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.000303   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.000495   |
# |    value_loss           | 54.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -26.1       |
# | time/                   |             |
# |    fps                  | 1711        |
# |    iterations           | 6           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.004730569 |
# |    clip_fraction        | 0.0278      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -3.21e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.5        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.000664    |
# |    value_loss           | 74.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -24        |
# | time/                   |            |
# |    fps                  | 1694       |
# |    iterations           | 7          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.00828246 |
# |    clip_fraction        | 0.0835     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 1.47e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 32.2       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00929   |
# |    value_loss           | 76.1       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -22          |
# | time/                   |              |
# |    fps                  | 1680         |
# |    iterations           | 8            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0029344745 |
# |    clip_fraction        | 0.0326       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | -5.87e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.7         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 74.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -22.2       |
# | time/                   |             |
# |    fps                  | 1671        |
# |    iterations           | 9           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008169617 |
# |    clip_fraction        | 0.051       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -2.46e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.5        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00395    |
# |    value_loss           | 82          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -21.8       |
# | time/                   |             |
# |    fps                  | 1664        |
# |    iterations           | 10          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.013452166 |
# |    clip_fraction        | 0.0792      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.00021     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.2        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00507    |
# |    value_loss           | 66.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -23.1        |
# | time/                   |              |
# |    fps                  | 1658         |
# |    iterations           | 11           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0069935163 |
# |    clip_fraction        | 0.0658       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.000414    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.4         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00477     |
# |    value_loss           | 67.8         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -22.8      |
# | time/                   |            |
# |    fps                  | 1649       |
# |    iterations           | 12         |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.00811631 |
# |    clip_fraction        | 0.0803     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | -0.00012   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 34.9       |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0048    |
# |    value_loss           | 71.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -21         |
# | time/                   |             |
# |    fps                  | 1647        |
# |    iterations           | 13          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.015046913 |
# |    clip_fraction        | 0.0941      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.00385    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.2        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00678    |
# |    value_loss           | 76          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -16.6       |
# | time/                   |             |
# |    fps                  | 1642        |
# |    iterations           | 14          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.005218203 |
# |    clip_fraction        | 0.0375      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -1.94e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.2        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00256    |
# |    value_loss           | 64.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -14          |
# | time/                   |              |
# |    fps                  | 1638         |
# |    iterations           | 15           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0053532785 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 4.78e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.7         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 65.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -11.8        |
# | time/                   |              |
# |    fps                  | 1636         |
# |    iterations           | 16           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0066060084 |
# |    clip_fraction        | 0.13         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.982       |
# |    explained_variance   | -0.00395     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.6         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00905     |
# |    value_loss           | 66.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -10.9        |
# | time/                   |              |
# |    fps                  | 1635         |
# |    iterations           | 17           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0083925985 |
# |    clip_fraction        | 0.157        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.976       |
# |    explained_variance   | 0.000446     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.7         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0125      |
# |    value_loss           | 61.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -8          |
# | time/                   |             |
# |    fps                  | 1630        |
# |    iterations           | 18          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.005609287 |
# |    clip_fraction        | 0.0767      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.978      |
# |    explained_variance   | -0.0181     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25          |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00348    |
# |    value_loss           | 67.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -3.12       |
# | time/                   |             |
# |    fps                  | 1626        |
# |    iterations           | 19          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005207223 |
# |    clip_fraction        | 0.0931      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.993      |
# |    explained_variance   | -0.000693   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.4        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0058     |
# |    value_loss           | 52.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 4.56        |
# | time/                   |             |
# |    fps                  | 1624        |
# |    iterations           | 20          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004100922 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.998      |
# |    explained_variance   | -0.00886    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.3        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00591    |
# |    value_loss           | 60.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 11.8        |
# | time/                   |             |
# |    fps                  | 1624        |
# |    iterations           | 21          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008077266 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.000583    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.7        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0155     |
# |    value_loss           | 37.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 1622        |
# |    iterations           | 22          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.006046816 |
# |    clip_fraction        | 0.0853      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.99       |
# |    explained_variance   | 0.000156    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.2        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00303    |
# |    value_loss           | 37.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 24           |
# | time/                   |              |
# |    fps                  | 1621         |
# |    iterations           | 23           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0066503566 |
# |    clip_fraction        | 0.143        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | -0.000151    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.3         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | 0.000773     |
# |    value_loss           | 33.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 26.4         |
# | time/                   |              |
# |    fps                  | 1620         |
# |    iterations           | 24           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0067846463 |
# |    clip_fraction        | 0.147        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 9.72e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11           |
# |    n_updates            | 230          |
# |    policy_gradient_loss | 0.000596     |
# |    value_loss           | 30.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 29.5        |
# | time/                   |             |
# |    fps                  | 1618        |
# |    iterations           | 25          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.007623072 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.000251   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.9        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00543    |
# |    value_loss           | 41.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 32          |
# | time/                   |             |
# |    fps                  | 1615        |
# |    iterations           | 26          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.012311434 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | -3.54e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.5        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.00296     |
# |    value_loss           | 46.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 33.2         |
# | time/                   |              |
# |    fps                  | 1614         |
# |    iterations           | 27           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0079101175 |
# |    clip_fraction        | 0.173        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.994       |
# |    explained_variance   | -8.34e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.4         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | 0.00512      |
# |    value_loss           | 42.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 35          |
# | time/                   |             |
# |    fps                  | 1613        |
# |    iterations           | 28          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010063786 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.982      |
# |    explained_variance   | 4.35e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24          |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00346    |
# |    value_loss           | 53          |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 60        |
# |    ep_rew_mean          | 38.4      |
# | time/                   |           |
# |    fps                  | 1613      |
# |    iterations           | 29        |
# |    time_elapsed         | 36        |
# |    total_timesteps      | 59392     |
# | train/                  |           |
# |    approx_kl            | 0.0089329 |
# |    clip_fraction        | 0.201     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.987    |
# |    explained_variance   | 1.23e-05  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 31.5      |
# |    n_updates            | 280       |
# |    policy_gradient_loss | 0.0086    |
# |    value_loss           | 57.4      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 41.2        |
# | time/                   |             |
# |    fps                  | 1611        |
# |    iterations           | 30          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.010409421 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.988      |
# |    explained_variance   | -8.34e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27          |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00295     |
# |    value_loss           | 57.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 43          |
# | time/                   |             |
# |    fps                  | 1610        |
# |    iterations           | 31          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.010288232 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.969      |
# |    explained_variance   | 8.94e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.7        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.00484     |
# |    value_loss           | 66.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 42.8        |
# | time/                   |             |
# |    fps                  | 1609        |
# |    iterations           | 32          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011134208 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.966      |
# |    explained_variance   | -1.13e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.5        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.00265     |
# |    value_loss           | 74.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 42.5        |
# | time/                   |             |
# |    fps                  | 1607        |
# |    iterations           | 33          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.026869874 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.949      |
# |    explained_variance   | 4.71e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.1        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.0115      |
# |    value_loss           | 71.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 42.5        |
# | time/                   |             |
# |    fps                  | 1603        |
# |    iterations           | 34          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.011954706 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.961      |
# |    explained_variance   | -1.45e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.7        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00172    |
# |    value_loss           | 72.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44.3        |
# | time/                   |             |
# |    fps                  | 1600        |
# |    iterations           | 35          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.035748906 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.947      |
# |    explained_variance   | -1.79e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.7        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.0102      |
# |    value_loss           | 77          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 46.3       |
# | time/                   |            |
# |    fps                  | 1599       |
# |    iterations           | 36         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.01123387 |
# |    clip_fraction        | 0.207      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.948     |
# |    explained_variance   | -4.41e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 31.3       |
# |    n_updates            | 350        |
# |    policy_gradient_loss | 0.0112     |
# |    value_loss           | 75.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.2        |
# | time/                   |             |
# |    fps                  | 1599        |
# |    iterations           | 37          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.014857268 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.93       |
# |    explained_variance   | -1.79e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.5        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.0071      |
# |    value_loss           | 82.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.3        |
# | time/                   |             |
# |    fps                  | 1599        |
# |    iterations           | 38          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.017342024 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.943      |
# |    explained_variance   | -3.1e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.6        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00528     |
# |    value_loss           | 82.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.8        |
# | time/                   |             |
# |    fps                  | 1598        |
# |    iterations           | 39          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.029047132 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.955      |
# |    explained_variance   | 3.7e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.6        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00805     |
# |    value_loss           | 88.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 43.4        |
# | time/                   |             |
# |    fps                  | 1597        |
# |    iterations           | 40          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.017348008 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.944      |
# |    explained_variance   | -2.03e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.3        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.0108      |
# |    value_loss           | 84.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 43          |
# | time/                   |             |
# |    fps                  | 1598        |
# |    iterations           | 41          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.011678053 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.935      |
# |    explained_variance   | 4.83e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.3        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0033     |
# |    value_loss           | 82          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 43.7        |
# | time/                   |             |
# |    fps                  | 1597        |
# |    iterations           | 42          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.020750048 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.944      |
# |    explained_variance   | 1.42e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.3        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.0039      |
# |    value_loss           | 76.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 48.6         |
# | time/                   |              |
# |    fps                  | 1597         |
# |    iterations           | 43           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0088048205 |
# |    clip_fraction        | 0.193        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.947       |
# |    explained_variance   | 5.3e-06      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.5         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 0.00872      |
# |    value_loss           | 77.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.9        |
# | time/                   |             |
# |    fps                  | 1597        |
# |    iterations           | 44          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.010722827 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.939      |
# |    explained_variance   | 1.07e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.4        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.0115      |
# |    value_loss           | 83.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.6        |
# | time/                   |             |
# |    fps                  | 1598        |
# |    iterations           | 45          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.008537699 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.932      |
# |    explained_variance   | -2.03e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.5        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00763     |
# |    value_loss           | 88          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.5        |
# | time/                   |             |
# |    fps                  | 1598        |
# |    iterations           | 46          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.016690558 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.942      |
# |    explained_variance   | 1.25e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 57.3        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00532     |
# |    value_loss           | 93.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.9        |
# | time/                   |             |
# |    fps                  | 1597        |
# |    iterations           | 47          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.017214274 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.939      |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.7        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.0096      |
# |    value_loss           | 92.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 52.1        |
# | time/                   |             |
# |    fps                  | 1597        |
# |    iterations           | 48          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011844292 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.941      |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.9        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.0134      |
# |    value_loss           | 96.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 53          |
# | time/                   |             |
# |    fps                  | 1597        |
# |    iterations           | 49          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.016848542 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.931      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.4        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00862     |
# |    value_loss           | 97.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 53.5         |
# | time/                   |              |
# |    fps                  | 1598         |
# |    iterations           | 50           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0101925135 |
# |    clip_fraction        | 0.177        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.938       |
# |    explained_variance   | 2.98e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63.8         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | 0.00913      |
# |    value_loss           | 99.2         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 53.9       |
# | time/                   |            |
# |    fps                  | 1598       |
# |    iterations           | 51         |
# |    time_elapsed         | 65         |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.02678323 |
# |    clip_fraction        | 0.259      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.927     |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 40.7       |
# |    n_updates            | 500        |
# |    policy_gradient_loss | 0.0144     |
# |    value_loss           | 102        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 53.7        |
# | time/                   |             |
# |    fps                  | 1598        |
# |    iterations           | 52          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.011554349 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.931      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.4        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.0154      |
# |    value_loss           | 108         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 53.3        |
# | time/                   |             |
# |    fps                  | 1599        |
# |    iterations           | 53          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.021399204 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.928      |
# |    explained_variance   | 6.56e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.2        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | 0.012       |
# |    value_loss           | 105         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 52.6       |
# | time/                   |            |
# |    fps                  | 1600       |
# |    iterations           | 54         |
# |    time_elapsed         | 69         |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.03575035 |
# |    clip_fraction        | 0.203      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.914     |
# |    explained_variance   | 3.58e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 56.5       |
# |    n_updates            | 530        |
# |    policy_gradient_loss | 0.00947    |
# |    value_loss           | 101        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.3        |
# | time/                   |             |
# |    fps                  | 1600        |
# |    iterations           | 55          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.005297874 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.8        |
# |    n_updates            | 540         |
# ...
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57.1        |
# | time/                   |             |
# |    fps                  | 1577        |
# |    iterations           | 179         |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 366592      |
# | train/                  |             |
# |    approx_kl            | 0.008387655 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.729      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59          |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | 0.0113      |
# |    value_loss           | 118         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57.5        |
# | time/                   |             |
# |    fps                  | 1577        |
# |    iterations           | 180         |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.009739948 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.697      |
# |    explained_variance   | -4.17e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.2        |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | 0.00475     |
# |    value_loss           | 118         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 57.2       |
# | time/                   |            |
# |    fps                  | 1578       |
# |    iterations           | 181        |
# |    time_elapsed         | 234        |
# |    total_timesteps      | 370688     |
# | train/                  |            |
# |    approx_kl            | 0.01251895 |
# |    clip_fraction        | 0.149      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.71      |
# |    explained_variance   | 1.01e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 64.6       |
# |    n_updates            | 1800       |
# |    policy_gradient_loss | 0.0103     |
# |    value_loss           | 118        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.6        |
# | time/                   |             |
# |    fps                  | 1578        |
# |    iterations           | 182         |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 372736      |
# | train/                  |             |
# |    approx_kl            | 0.013615425 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.688      |
# |    explained_variance   | -1.19e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 60.7        |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | 0.0069      |
# |    value_loss           | 119         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.6        |
# | time/                   |             |
# |    fps                  | 1579        |
# |    iterations           | 183         |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 374784      |
# | train/                  |             |
# |    approx_kl            | 0.033856377 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.693      |
# |    explained_variance   | -2.62e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 60.2        |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | 0.0121      |
# |    value_loss           | 114         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.6        |
# | time/                   |             |
# |    fps                  | 1579        |
# |    iterations           | 184         |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.019039705 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.711      |
# |    explained_variance   | 4.17e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.2        |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | 0.00716     |
# |    value_loss           | 115         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57.4        |
# | time/                   |             |
# |    fps                  | 1580        |
# |    iterations           | 185         |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 378880      |
# | train/                  |             |
# |    approx_kl            | 0.023335097 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.723      |
# |    explained_variance   | -2.26e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65.1        |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | 0.0126      |
# |    value_loss           | 116         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57.4        |
# | time/                   |             |
# |    fps                  | 1580        |
# |    iterations           | 186         |
# |    time_elapsed         | 241         |
# |    total_timesteps      | 380928      |
# | train/                  |             |
# |    approx_kl            | 0.011678318 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.709      |
# |    explained_variance   | 3.7e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.9        |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | 0.00654     |
# |    value_loss           | 116         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57.4        |
# | time/                   |             |
# |    fps                  | 1580        |
# |    iterations           | 187         |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 382976      |
# | train/                  |             |
# |    approx_kl            | 0.018029917 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.738      |
# |    explained_variance   | 1.13e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 73.6        |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | 0.00723     |
# |    value_loss           | 117         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 57.4         |
# | time/                   |              |
# |    fps                  | 1581         |
# |    iterations           | 188          |
# |    time_elapsed         | 243          |
# |    total_timesteps      | 385024       |
# | train/                  |              |
# |    approx_kl            | 0.0104364995 |
# |    clip_fraction        | 0.153        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.721       |
# |    explained_variance   | -1.67e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 59.3         |
# |    n_updates            | 1870         |
# |    policy_gradient_loss | 0.00738      |
# |    value_loss           | 119          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57.7        |
# | time/                   |             |
# |    fps                  | 1581        |
# |    iterations           | 189         |
# |    time_elapsed         | 244         |
# |    total_timesteps      | 387072      |
# | train/                  |             |
# |    approx_kl            | 0.018525617 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.703      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65.3        |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | 0.0103      |
# |    value_loss           | 118         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57.9        |
# | time/                   |             |
# |    fps                  | 1582        |
# |    iterations           | 190         |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.021889843 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.688      |
# |    explained_variance   | -1.07e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 76.9        |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | 0.0106      |
# |    value_loss           | 119         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57.9        |
# | time/                   |             |
# |    fps                  | 1582        |
# |    iterations           | 191         |
# |    time_elapsed         | 247         |
# |    total_timesteps      | 391168      |
# | train/                  |             |
# |    approx_kl            | 0.007042134 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | -1.19e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.4        |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | 0.0125      |
# |    value_loss           | 119         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57.4        |
# | time/                   |             |
# |    fps                  | 1583        |
# |    iterations           | 192         |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.010841208 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.674      |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61.2        |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | 0.00916     |
# |    value_loss           | 118         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.3        |
# | time/                   |             |
# |    fps                  | 1583        |
# |    iterations           | 193         |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 395264      |
# | train/                  |             |
# |    approx_kl            | 0.026340254 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.702      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61.3        |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | 0.01        |
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 55.9        |
# | time/                   |             |
# |    fps                  | 1584        |
# |    iterations           | 194         |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 397312      |
# | train/                  |             |
# |    approx_kl            | 0.018766176 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.724      |
# |    explained_variance   | 4.17e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.3        |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | 0.00955     |
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56          |
# | time/                   |             |
# |    fps                  | 1584        |
# |    iterations           | 195         |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 399360      |
# | train/                  |             |
# |    approx_kl            | 0.009905722 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.719      |
# |    explained_variance   | 1.79e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.4        |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | 0.00948     |
# |    value_loss           | 115         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57          |
# | time/                   |             |
# |    fps                  | 1585        |
# |    iterations           | 196         |
# |    time_elapsed         | 253         |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.024667934 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.755      |
# |    explained_variance   | -1.43e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.2        |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | 0.0115      |
# |    value_loss           | 117         |
# -----------------------------------------

# %% [markdown]
# # 6. Save Model

# %%
model.save('PPO')

# %%
evaluate_policy(model, env, n_eval_episodes=100, render=False)
# Out:
# (59.54, 0.8416650165000326)
