# %%
# https://stable-baselines3.readthedocs.io/en/master/guide/rl.html
# https://spinningup.openai.com/en/latest/spinningup/rl_intro2.html#a-taxonomy-of-rl-algorithms

# %% [markdown]
# # 1. Import dependencies

# %%
# !pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: stable-baselines3[extra] in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (1.1.0)
# Requirement already satisfied: torch>=1.4.0 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from stable-baselines3[extra]) (1.9.0)
# Requirement already satisfied: cloudpickle in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from stable-baselines3[extra]) (1.6.0)
# Requirement already satisfied: numpy in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from stable-baselines3[extra]) (1.18.5)
# Requirement already satisfied: gym>=0.17 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from stable-baselines3[extra]) (0.18.3)
# Requirement already satisfied: matplotlib in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from stable-baselines3[extra]) (3.4.2)
# Requirement already satisfied: pandas in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: atari-py~=0.2.0 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from stable-baselines3[extra]) (0.2.6)
# Requirement already satisfied: psutil in /home/zboucek/.local/lib/python3.8/site-packages (from stable-baselines3[extra]) (5.8.0)
# Requirement already satisfied: opencv-python in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from stable-baselines3[extra]) (4.5.2.52)
# Requirement already satisfied: pillow in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from stable-baselines3[extra]) (8.2.0)
# Requirement already satisfied: tensorboard>=2.2.0 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from stable-baselines3[extra]) (2.5.0)
# Requirement already satisfied: six in /home/zboucek/.local/lib/python3.8/site-packages (from atari-py~=0.2.0->stable-baselines3[extra]) (1.15.0)
# Requirement already satisfied: scipy in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from gym>=0.17->stable-baselines3[extra]) (1.6.3)
# Requirement already satisfied: pyglet<=1.5.15,>=1.4.0 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from gym>=0.17->stable-baselines3[extra]) (1.5.15)
# Requirement already satisfied: setuptools>=41.0.0 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (52.0.0.post20210125)
# Requirement already satisfied: wheel>=0.26 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.36.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.30.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.8.0)
# Requirement already satisfied: protobuf>=3.6.0 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (3.17.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/zboucek/.local/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.25.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.0.1)
# Requirement already satisfied: grpcio>=1.24.3 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.37.1)
# Requirement already satisfied: absl-py>=0.4 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.12.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (3.3.4)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /home/zboucek/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[extra]) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/zboucek/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[extra]) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[extra]) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/zboucek/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[extra]) (1.26.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]) (3.1.0)
# Requirement already satisfied: typing-extensions in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from torch>=1.4.0->stable-baselines3[extra]) (3.10.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /home/zboucek/anaconda3/envs/rl/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/zboucek/.local/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /home/zboucek/.local/lib/python3.8/site-packages (from pandas->stable-baselines3[extra]) (2021.1)

# %%
import gym 
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Load Environment

# %%
environment_name = "CartPole-v0"

# %%
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:12.0
# Episode:2 Score:8.0
# Episode:3 Score:10.0
# Episode:4 Score:57.0
# Episode:5 Score:17.0

# %% [markdown]
# # Understanding The Environment
# https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py

# %%
# 0-push cart to left, 1-push cart to the right
env.action_space.sample()
# Out:
# 0

# %%
# [cart position, cart velocity, pole angle, pole angular velocity]
env.observation_space.sample()
# Out:
# array([-9.8953247e-01, -1.9005155e+38,  4.0061706e-01,  3.0971712e+36],
#       dtype=float32)

# %% [markdown]
# # 3. Train an RL Model

# %%
log_path = os.path.join('Training','Logs')

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log = log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training/Logs/PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 1518 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1564       |
# |    iterations           | 2          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00923532 |
# |    clip_fraction        | 0.0984     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.686     |
# |    explained_variance   | -0.00721   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.68       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0138    |
# |    value_loss           | 47.3       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1588        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008348824 |
# |    clip_fraction        | 0.0405      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.668      |
# |    explained_variance   | 0.0765      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 35.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1606        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008644824 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.251       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0213     |
# |    value_loss           | 47.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1615         |
# |    iterations           | 5            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0104723675 |
# |    clip_fraction        | 0.0978       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.604       |
# |    explained_variance   | 0.258        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.1         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.018       |
# |    value_loss           | 66.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1621        |
# |    iterations           | 6           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007910571 |
# |    clip_fraction        | 0.0805      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.594      |
# |    explained_variance   | 0.275       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27          |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 66.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1624         |
# |    iterations           | 7            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0102761295 |
# |    clip_fraction        | 0.0823       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.574       |
# |    explained_variance   | 0.611        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.8         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0147      |
# |    value_loss           | 58.5         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1629       |
# |    iterations           | 8          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00537013 |
# |    clip_fraction        | 0.0491     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.573     |
# |    explained_variance   | 0.614      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.96       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00864   |
# |    value_loss           | 61.6       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1632        |
# |    iterations           | 9           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.002309484 |
# |    clip_fraction        | 0.00151     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.576      |
# |    explained_variance   | 0.613       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.3        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00084    |
# |    value_loss           | 59.7        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1633       |
# |    iterations           | 10         |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00366861 |
# |    clip_fraction        | 0.0305     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.582     |
# |    explained_variance   | 0.533      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 28.1       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00396   |
# |    value_loss           | 65.8       |
# ----------------------------------------

# %% [markdown]
# # 4. Save and Reload Model

# %%
PPO_path = os.path.join('Training', 'Saved Models', 'PPO_model')

# %%
model.save(PPO_path)

# %%
del model

# %%
model = PPO.load(PPO_path, env=env)

# %% [markdown]
# # 4. Evaluation

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# (200.0, 0.0)

# %%
env.close()

# %% [markdown]
# # 5. Test Model

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    env.render()
    if done: 
        print('info', info)
        break
# Out:
# info [{'TimeLimit.truncated': True, 'terminal_observation': array([ 0.12805162,  0.36724651, -0.07095085, -0.49571828])}]

# %%
env.close()

# %% [markdown]
# # 6. Viewing Logs in Tensorboard

# %%
training_log_path = os.path.join(log_path, 'PPO_1')

# %%
# !tensorboard --logdir={training_log_path}
# Out:
# 2021-08-03 15:59:27.654375: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.5.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %% [markdown]
# # 7. Adding a callback to the training Stage

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'Saved Models')
log_path = os.path.join('Training', 'Logs')

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=190, verbose=1)
eval_callback = EvalCallback(env, 
                             callback_on_new_best=stop_callback, 
                             eval_freq=10000, 
                             best_model_save_path=save_path, 
                             verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 2787 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1941         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0078740455 |
# |    clip_fraction        | 0.0615       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.687       |
# |    explained_variance   | 0.00252      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.95         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00869     |
# |    value_loss           | 49.4         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1734        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012981227 |
# |    clip_fraction        | 0.0985      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0207     |
# |    value_loss           | 27.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1657        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008616957 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.625      |
# |    explained_variance   | 0.279       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0205     |
# |    value_loss           | 45.6        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=186.20 +/- 27.60
# Episode length: 186.20 +/- 27.60
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 186          |
# |    mean_reward          | 186          |
# | time/                   |              |
# |    total timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0049656667 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.618       |
# |    explained_variance   | 0.248        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.4         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0102      |
# |    value_loss           | 54.9         |
# ------------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 1544  |
# |    iterations      | 5     |
# |    time_elapsed    | 6     |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1525        |
# |    iterations           | 6           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.006447146 |
# |    clip_fraction        | 0.0773      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.599      |
# |    explained_variance   | 0.638       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.7        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 42.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1516         |
# |    iterations           | 7            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0078883115 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.593       |
# |    explained_variance   | 0.656        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.4         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0167      |
# |    value_loss           | 55.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1500        |
# |    iterations           | 8           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006999419 |
# |    clip_fraction        | 0.0534      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.575      |
# |    explained_variance   | 0.497       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.6        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00872    |
# |    value_loss           | 69.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1482        |
# |    iterations           | 9           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.003945387 |
# |    clip_fraction        | 0.0298      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.564      |
# |    explained_variance   | 0.697       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.6        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00825    |
# |    value_loss           | 51.6        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0076201493 |
# |    clip_fraction        | 0.0728       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.567       |
# |    explained_variance   | 0.698        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.5         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0065      |
# |    value_loss           | 57.6         |
# ------------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 190

# %%
model_path = os.path.join('Training', 'Saved Models', 'best_model')
model = PPO.load(model_path, env=env)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# (200.0, 0.0)

# %%
env.close()

# %% [markdown]
# # 8. Changing Policies

# %%
net_arch=[dict(pi=[128, 128, 128, 128], vf=[128, 128, 128, 128])]

# %%
model = PPO('MlpPolicy', env, verbose = 1, policy_kwargs={'net_arch': net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 2056 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1326        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013610125 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | 0.000569    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.66        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0218     |
# |    value_loss           | 20.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1188        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015221845 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.648      |
# |    explained_variance   | 0.385       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.031      |
# |    value_loss           | 28.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1134        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013853161 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.603      |
# |    explained_variance   | 0.401       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.027      |
# |    value_loss           | 46.6        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.012033083 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.571      |
# |    explained_variance   | 0.446       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0198     |
# |    value_loss           | 45.7        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 1062  |
# |    iterations      | 5     |
# |    time_elapsed    | 9     |
# |    total_timesteps | 10240 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1050         |
# |    iterations           | 6            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0069928346 |
# |    clip_fraction        | 0.0832       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.547       |
# |    explained_variance   | 0.7          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.01         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00622     |
# |    value_loss           | 31.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1045        |
# |    iterations           | 7           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009378545 |
# |    clip_fraction        | 0.0757      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.526      |
# |    explained_variance   | 0.711       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.2        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00349    |
# |    value_loss           | 38.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1041         |
# |    iterations           | 8            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0062525244 |
# |    clip_fraction        | 0.0498       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.514       |
# |    explained_variance   | 0.646        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.4         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00251     |
# |    value_loss           | 53           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1038        |
# |    iterations           | 9           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007274964 |
# |    clip_fraction        | 0.0934      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.516      |
# |    explained_variance   | 0.827       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.3        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00623    |
# |    value_loss           | 34.5        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0055106254 |
# |    clip_fraction        | 0.058        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.516       |
# |    explained_variance   | 0.588        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.7         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 65.7         |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 1010  |
# |    iterations      | 10    |
# |    time_elapsed    | 20    |
# |    total_timesteps | 20480 |
# ------------------------------

# %% [markdown]
# # 9. Using an Alternate Algorithm

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training/Logs/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.951    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 4237     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 104      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.91     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 5382     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 189      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.845    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 7061     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 327      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.8      |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 7917     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 422      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.752    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 8579     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 522      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.722    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 8747     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 586      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.682    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 9123     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 669      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.636    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 9582     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 767      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.603    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 9802     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 835      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.555    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 9930     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 936      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.533    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 9941     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 984      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.502    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 10104    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1048     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.427    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 10492    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1207     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.396    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 10585    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1271     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.36     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 10723    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1347     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.318    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 10753    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1435     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.282    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 10858    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1511     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.243    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 10999    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1594     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.2      |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 11177    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1684     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.16     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 11293    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1769     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.117    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 11288    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1860     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.0837   |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 11333    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1929     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 11476    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2019     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 11557    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2101     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 11633    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2176     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 11692    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2260     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 11766    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2374     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 11841    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2455     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 11903    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2528     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 11870    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2618     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 11931    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2706     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 11903    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2768     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 11963    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2851     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 12022    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2946     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 12094    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3034     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 12120    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 12167    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3248     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 12207    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3326     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 12250    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3418     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 12268    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3490     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 12307    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3572     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 12295    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3644     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 12378    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3779     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 12407    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3858     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 12437    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3939     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 12455    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4030     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 12447    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4099     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 12388    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4167     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 12402    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4237     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 12490    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4398     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 12492    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4507     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 12531    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4620     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 12548    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4688     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 12583    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4773     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 12557    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4829     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 12566    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4909     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 12551    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4983     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 12573    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5061     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 12612    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5155     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 12626    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5218     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 12643    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5310     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 12662    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5393     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 12706    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5524     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 12735    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5605     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 12764    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5730     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 12784    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5816     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 12796    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5933     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 12810    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6031     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 12808    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6095     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 12825    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6184     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 12854    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6283     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 12847    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 12813    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6419     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 12831    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6489     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 12850    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6579     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 12862    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6659     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 12885    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6753     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 12864    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6841     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 12870    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6913     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 12889    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7005     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 12895    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7070     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 12883    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7122     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 12906    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7226     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 12870    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7317     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 12886    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7417     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 12900    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7497     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 12885    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7612     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 12844    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7670     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 12804    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7740     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 12814    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7819     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 12810    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7873     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 12811    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7955     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 12796    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8092     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 12803    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8167     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 12822    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8259     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 12829    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8325     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 12837    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8402     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 12858    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8510     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 12877    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8610     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 12890    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8694     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 12906    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8795     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 12920    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8882     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 12886    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8931     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 12888    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9006     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 12889    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9059     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 12903    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9152     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 12893    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9215     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 12904    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9310     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 12904    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9392     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 12892    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9507     |
# ----------------------------------
# Eval num_timesteps=9520, episode_reward=9.60 +/- 0.49
# Episode length: 9.60 +/- 0.49
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 9.6      |
# |    mean_reward      | 9.6      |
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    total timesteps  | 9520     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 12410    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9581     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 12433    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9732     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 12451    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9826     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 12461    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9984     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 11943    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10111    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 11945    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10194    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 11949    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10291    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 11944    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10367    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 11953    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10439    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 11962    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10494    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 11969    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10591    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 11972    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10681    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 11981    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10775    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 11987    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10845    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 11995    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10910    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 12000    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 12012    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11091    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 12014    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11182    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 12017    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11272    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 12035    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11368    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 12024    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11437    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 12018    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11532    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 12009    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11615    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 12033    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11741    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 12048    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11837    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 12052    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11896    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 12055    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11990    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 12049    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12078    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 12068    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12168    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 12084    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12262    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 12110    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12384    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 12126    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12486    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 12135    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 12167    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12711    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 12175    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 12195    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12886    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 12202    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12993    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 12211    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13072    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 12220    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13141    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 12227    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13209    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 12246    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13333    |
# ----------------------------------
# ...
# |    fps              | 12381    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15505    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 12392    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15590    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 12392    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15654    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 12396    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15740    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 12402    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15819    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 12412    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15905    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 12415    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15961    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 12420    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16023    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 12434    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16154    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 12445    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16245    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 12451    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16318    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 12462    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16404    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 12472    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16498    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 12469    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16575    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 12473    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16668    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 12478    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16735    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 12479    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16790    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 12482    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16869    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 12486    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16973    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 12491    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 12499    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17129    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 12506    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17255    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 12511    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 12516    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17422    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 12514    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17516    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 12525    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17617    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 12536    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17755    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 12541    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17838    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 12543    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17914    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 12530    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17968    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 12536    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18046    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 12535    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18094    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 12541    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18168    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 12537    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18310    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 12527    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18365    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 12536    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18480    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 12520    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18605    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 12518    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18692    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 12490    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18767    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 12497    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18866    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 12505    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18953    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 12511    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19025    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 12527    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19155    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 12523    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19253    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 12535    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19358    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 12552    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19498    |
# ----------------------------------
# Eval num_timesteps=19520, episode_reward=9.20 +/- 0.40
# Episode length: 9.20 +/- 0.40
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 9.2      |
# |    mean_reward      | 9.2      |
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    total timesteps  | 19520    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 12457    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19599    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 12461    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19694    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 12459    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19788    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 892      |
# |    fps              | 12404    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19915    |
# ----------------------------------

# %%
dqn_path = os.path.join('Training', 'Saved Models', 'DQN_model')

# %%
model.save(dqn_path)

# %%
model = DQN.load(dqn_path, env=env)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# (9.2, 0.8717797887081348)

# %%
env.close()
